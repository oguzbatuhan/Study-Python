# %%
class Person():
    #property
    #name = ''
    #age = 0
    #gender = ''
    job = ''

    #initializer method
    def __init__(self, name, age, gender):
        self.name = name
        self.age = age
        self.gender = gender

    #method
    def printName(self):
        print(self.name)

# %%
oguz = Person('oguz', 23, 'male')

# %%
type(oguz)
# Out:
# __main__.Person

# %%
oguz.name
# Out:
# 'oguz'

# %%
oguz.printName()
# Out:
# oguz

# %%
oguz.job = 'developer'

# %%
oguz.job
# Out:
# 'developer'

# %%
class Dog():

    year = 7

    def __init__(self,age=1):
        self.age = age
        self.dogHumanAge = age * self.year

    def humanAge(self):
        return self.age * Dog.year #Dog.year -> self.year

# %%
dog = Dog(5)

# %%
dog.age
# Out:
# 5

# %%
dog.humanAge()
# Out:
# 35

# %%
dog.dogHumanAge
# Out:
# 35

# %%
barly = Dog()

# %%
barly.age
# Out:
# 1
