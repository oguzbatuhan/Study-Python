# %%
myString : str = 'Oguz Batuhan'

# %%
myAge : int = 23

# %%
myBithday : str = '11.09.2003'

# %%
myNumber : str = 11

# %%
type(myNumber)
# Out:
# int

# %%
def mySum(a : int,b : int) -> int:
    return int(a) + int(b)
print(mySum(11,9))
type(mySum(11,9))
# Out:
# 20
# int

# %%
def mySum(a : str,b : str) -> str:
    return str(a) + str(b)
print(mySum(11,9))
type(mySum(11,9))
# Out:
# 119
# str
